# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("netflixData.csv")
data
# Out:
#                                    Show Id                          Title  \
# 0     cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1     e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2     b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3     b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4     7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
# ...                                    ...                            ...
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d                      الف مبروك
# 5963  5bed77ab-5e31-4216-8b51-44c9a35442e6                   دفعة القاهرة
# 5964  4661ec0c-8692-4661-bc76-a96412b311fd                           海的儿子
# 5965  145c93a7-1924-403c-a933-4ede8ad66f26                        반드시 잡는다
# 5966  d4613d34-cb71-4bd6-b570-fa857f02c44d            최강전사 미니특공대 : 영웅의 탄생
#
#                                             Description  \
# ...

# %%
data.tail()
# Out:
#                                    Show Id                Title  \
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d            الف مبروك
# 5963  5bed77ab-5e31-4216-8b51-44c9a35442e6         دفعة القاهرة
# 5964  4661ec0c-8692-4661-bc76-a96412b311fd                 海的儿子
# 5965  145c93a7-1924-403c-a933-4ede8ad66f26              반드시 잡는다
# 5966  d4613d34-cb71-4bd6-b570-fa857f02c44d  최강전사 미니특공대 : 영웅의 탄생
#
#                                             Description           Director  \
# 5962  On his wedding day, an arrogant, greedy accoun...  Ahmed Nader Galal
# 5963  A group of women leaves Kuwait to attend unive...                NaN
# 5964  Two brothers start a new life in Singapore, wh...                NaN
# 5965  After people in his town start turning up dead...      Hong-seon Kim
# 5966  Miniforce, a special task force of elite range...      Young Jun Lee
#
#                                        Genres  \
# 5962   Comedies, Dramas, International Movies
# ...

# %%
data["Production Country"].replace(np.nan , "None" , inplace = True)

# %%
data.tail()
# Out:
#                                    Show Id                Title  \
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d            الف مبروك
# 5963  5bed77ab-5e31-4216-8b51-44c9a35442e6         دفعة القاهرة
# 5964  4661ec0c-8692-4661-bc76-a96412b311fd                 海的儿子
# 5965  145c93a7-1924-403c-a933-4ede8ad66f26              반드시 잡는다
# 5966  d4613d34-cb71-4bd6-b570-fa857f02c44d  최강전사 미니특공대 : 영웅의 탄생
#
#                                             Description           Director  \
# 5962  On his wedding day, an arrogant, greedy accoun...  Ahmed Nader Galal
# 5963  A group of women leaves Kuwait to attend unive...                NaN
# 5964  Two brothers start a new life in Singapore, wh...                NaN
# 5965  After people in his town start turning up dead...      Hong-seon Kim
# 5966  Miniforce, a special task force of elite range...      Young Jun Lee
#
#                                        Genres  \
# 5962   Comedies, Dramas, International Movies
# ...

# %%
product_countries = data["Production Country"][:30].value_counts().sort_values(ascending = False)
product_countries
# Out:
# United States            11
# Indonesia                 3
# South Korea               2
# India                     2
# Italy                     2
# Romania                   2
# Spain                     1
# Canada                    1
# Egypt                     1
# Portugal, Spain           1
# France                    1
# South Africa, Nigeria     1
# Mexico                    1
# Poland, United States     1
# Name: Production Country, dtype: int64

# %%
product_countries = data["Production Country"][:30].value_counts().plot(kind = "barh")
product_countries

# %%
plt.hist(product_countries , bins = 30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-0df77a232e8b> in <module>
# ----> 1 plt.hist(product_countries , bins = 30)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2641         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2642         color=color, label=label, stacked=stacked, normed=normed,
# -> 2643         **({"data": data} if data is not None else {}), **kwargs)
#    2644
#    2645
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
# ...
